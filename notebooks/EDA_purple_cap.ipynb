# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("/Workspace/Users/manikanthgoud98@gmail.com/ipl_data_modelling/data/raw/ipl_purple_cap.csv")
df.head()

# %%
df.shape

# %%
top_bowlers = df.sort_values(by=['year','wickets'], ascending=[False, False]).drop_duplicates('year')
top_bowlers
