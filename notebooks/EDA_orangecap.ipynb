# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Workspace/Users/manikanthgoud98@gmail.com/ipl_data_modelling/data/raw/ipl_orange_cap.csv")
df.head()

# %%
df.shape

# %%
df.info()

# %%
df["player"].nunique()

# %%
df.groupby("player").agg({"runs": "mean"}).sort_values("runs", ascending=False).head(10)

# %%
df_group_year = df.groupby("team").head()
df_group_year

# %%
top_batsmen = df.sort_values(['year', 'runs'], ascending=[True, False]) \
                .drop_duplicates('year')
top_batsmen.sort_values("year", ascending=False)
