# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Workspace/Users/manikanthgoud98@gmail.com/ipl_data_modelling/data/raw/ipl_team_stats.csv")

# %%
df

# %%
df.info()

# %%
df["team"].unique()

# %%
df["year"].unique()

# %%
df[df["nrr"].isnull()]

# %%
df.info()

# %%
df.shape

# %%
df["team"].unique()

# %%
df["year"].unique()

# %%
df["team"].value_counts()

# %%
df.groupby("team")["won"].sum()

# %%
df["total_wins"] = df.groupby("team")["won"].transform("sum")

# %%
df.groupby("team")["total_wins"].max()
